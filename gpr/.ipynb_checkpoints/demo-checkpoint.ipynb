# %%
import gpr
import pandas as pd
import numpy as np
import matplotlib.pylab as plt
import warnings
warnings.filterwarnings('ignore')
# %matplotlib inline

# %% [markdown]
# This notebook will provide a demo for how to estimate metallicities using our Gaussian Process Regressor. For the data used in this example, we will be using the first 50,000 rows from the Gaia high proper motion cross match from Medan, Lepine and Hartman (2020).

# %%
data=pd.read_csv('GAIA_DR2_star_40mas_best_bayes_matches_all_phot_GITHUB_SAMPLE_TAB.txt')

# %% [markdown]
# To use the provided code to estimate metallicites, data must be loaded as a Pandas dataframe with the same column names as the cross match table provided here. The column names for the table are printed below, and can be found in our paper.

# %%
print(data.columns)
# Out:
# Index(['GaiaDR2_ID', 'Gmag_GaiaDR2', 'BPmag_GaiaDR2', 'RPmag_GaiaDR2',
#        'RA_ICRS_GaiaDR2', 'DE_ICRS_GaiaDR2', 'PLX_GaiaDR2', 'PLXerr_GaiaDR2',
#        'PMRA_GaiaDR2', 'PMDE_GaiaDR2', 'SDSSDR12_ID', 'umag_SDSSDR12',
#        'umag_err_SDSSDR12', 'gmag_SDSSDR12', 'gmag_err_SDSSDR12',
#        'rmag_SDSSDR12', 'rmag_err_SDSSDR12', 'imag_SDSSDR12',
#        'imag_err_SDSSDR12', 'zmag_SDSSDR12', 'zmag_err_SDSSDR12',
#        'RA_ICRS_SDSSDR12', 'DE_ICRS_SDSSDR12', 'Bayes_Prob_SDSSDR12',
#        'Ang_Sep_SDSSDR12', '2MASS_ID', 'Jmag_2MASS', 'Jmag_err_2MASS',
#        'Hmag_2MASS', 'Hmag_err_2MASS', 'Ksmag_2MASS', 'Ksmag_err_2MASS',
#        'RA_J2000_2MASS', 'DE_J2000_2MASS', 'Bayes_Prob_2MASS', 'Ang_Sep_2MASS',
#        'AllWISE_ID', 'W1mag_AllWISE', 'W1mag_err_AllWISE', 'W2mag_AllWISE',
#        'W2mag_err_AllWISE', 'W3mag_AllWISE', 'W3mag_err_AllWISE',
#        'W4mag_AllWISE', 'W4mag_err_AllWISE', 'RA_J2000_AllWISE',
# ...

# %% [markdown]
# As done in the paper, we correct the measurments for exitncion using the 3D dust map from Green et al. (2019). We then  determine values of $A_\lambda$ for Pan-STARRS, assuming $R_V=3.1$, using the results from Schlafly et al. (2011), and $A_\lambda$ values for 2MASS and AllWISE using the results from Davenport et al. (2014). See these papers for details on the calculations below. As a note, to run this part of the demo you will need to download the 3D dustmap (https://dataverse.harvard.edu/dataset.xhtml?persistentId=doi:10.7910/DVN/2EJ9TX) and add it to the current working directory. This is done using the cose below:

# %%
from dustmaps.bayestar import BayestarQuery
from astropy.coordinates import SkyCoord
import astropy.units as u
import os

data['PLX_GaiaDR2'][data['PLX_GaiaDR2']<0]=np.nan

sc = SkyCoord(ra=np.array(data['RA_ICRS_GaiaDR2'])*u.deg, dec=np.array(data['DE_ICRS_GaiaDR2'])*u.deg,
             distance=(1000/np.array(data['PLX_GaiaDR2']))*u.pc)




bayestar = BayestarQuery(max_samples=2, version='bayestar2019')

ebv = bayestar(sc, mode='median')

data['gmag_PS1']-=3.172*ebv
data['rmag_PS1']-=2.271*ebv
data['imag_PS1']-=1.682*ebv
data['zmag_PS1']-=1.322*ebv
data['ymag_PS1']-=1.087*ebv
data['Jmag_2MASS']-=2.285*ebv*0.3
data['Hmag_2MASS']-=2.285*ebv*0.21
data['Ksmag_2MASS']-=2.285*ebv*0.15
data['W1mag_AllWISE']-=2.285*ebv*0.09
data['W2mag_AllWISE']-=2.285*ebv*0.05
# Out:
# Loading pixel_info ...
# Loading samples ...
# Loading best_fit ...
# Replacing NaNs in reliable distance estimates ...
# Sorting pixel_info ...
# Extracting hp_idx_sorted and data_idx at each nside ...
#   nside = 64
#   nside = 128
#   nside = 256
#   nside = 512
#   nside = 1024
# t = 38.608 s
#   pix_info:   0.809 s
#    samples:  18.498 s
#       best:   8.360 s
#        nan:   0.318 s
#       sort:  10.247 s
#        idx:   0.375 s

# %% [markdown]
# Since there are two calibrated relationships for two different stellar temperature regimes, we have to apply some temperature cuts (by color). In addition, with these cuts we will also ensure that all stars in the sample have the required photometry for each regressor. This is done below for the K dwarf regressor (i.e. 3500 < T < 5280 K) and M dwarf regressor (i.e. 2850 < T < 3500 K).

# %%
K_cols=['Ksmag_2MASS','gmag_PS1','W1mag_AllWISE','ymag_PS1','W2mag_AllWISE','Jmag_2MASS']
ev_strK="(data['PLX_GaiaDR2']>0) & (data['BPmag_GaiaDR2']-data['RPmag_GaiaDR2']>0.98) & (data['BPmag_GaiaDR2']-data['RPmag_GaiaDR2']<2.39) & (data['PLXerr_GaiaDR2']/data['PLX_GaiaDR2']<0.2) & (data['gmag_PS1']>13.5)"
for i in range(len(K_cols)):
    ev_strK+="& (abs(data['%s'])<99.)" % K_cols[i]
ev_K_cols=eval(ev_strK)

# %%
M_cols=['rmag_PS1','W1mag_AllWISE','imag_PS1','Ksmag_2MASS','gmag_PS1']
ev_strM="(data['PLX_GaiaDR2']>0) & (data['BPmag_GaiaDR2']-data['RPmag_GaiaDR2']>2.39) & (data['BPmag_GaiaDR2']-data['RPmag_GaiaDR2']<5) & (data['PLXerr_GaiaDR2']/data['PLX_GaiaDR2']<0.2) & (data['gmag_PS1']>13.5)"
for i in range(len(M_cols)):
    ev_strM+="& (abs(data['%s'])<99.)" % M_cols[i]
ev_M_cols=eval(ev_strM)

# %% [markdown]
# Now we can estimate the metallicities and the confidence on these estimates.

# %%
data['M_H']=99.
data['M_H_std']=99.

data['M_H'][ev_K_cols],data['M_H_std'][ev_K_cols]=gpr.estimate_metals_gpr(data[ev_K_cols],'K_dwarf_classifier.joblib.pkl','K_dwarf_cuts.pkl','K')
data['M_H'][ev_M_cols],data['M_H_std'][ev_M_cols]=gpr.estimate_metals_gpr(data[ev_M_cols],'M_dwarf_classifier.joblib.pkl','M_dwarf_cuts.pkl','M')

# %% [markdown]
# Now let us look at the results from the regressor. In these plots the left panel shows the estimated metallicities and the right panel the 95% confidence interval on these estimates.

# %%
plt.rcParams.update({'font.size': 16})
col1='gmag_PS1'
col2='ymag_PS1'
mag='gmag_PS1'
boundx=(0.5,3.25)
boundy=(5.5,15)

fig = plt.figure(figsize=(23,10))
ax = fig.add_subplot(1, 2, 1)
density=ax.scatter(data[col1][ev_K_cols & (data['M_H']!=99.)]-data[col2][ev_K_cols & (data['M_H']!=99.)],data[mag][ev_K_cols & (data['M_H']!=99.)]+5*np.log10(1e-3*data['PLX_GaiaDR2'][ev_K_cols & (data['M_H']!=99.)])+5,marker='.',c=data['M_H'][ev_K_cols & (data['M_H']!=99.)],vmin=-2,vmax=0.3)
#ax.grid()
fig.colorbar(density, label='Gaussian Proccess Regressor M/H')
ax.set_xlabel(r'$g-y$')
ax.set_ylabel(r'$M_g$')
ax.set_title('K and Early M Dwarfs')
ax.set_xlim(boundx)
ax.set_ylim(boundy)
ax.grid()
ax.invert_yaxis()

ax2 = fig.add_subplot(1, 2, 2)
density=ax2.scatter(data[col1][ev_K_cols & (data['M_H']!=99.)]-data[col2][ev_K_cols & (data['M_H']!=99.)],data[mag][ev_K_cols & (data['M_H']!=99.)]+5*np.log10(1e-3*data['PLX_GaiaDR2'][ev_K_cols & (data['M_H']!=99.)])+5,marker='.',c=data['M_H_std'][ev_K_cols & (data['M_H']!=99.)]*1.95,vmin=0.1,vmax=0.5)
#ax.grid()
fig.colorbar(density, label=r'Gaussian Proccess Regressor $1.95\sigma_{M/H}$')
ax2.set_xlabel(r'$g-y$')
ax2.set_ylabel(r'$M_g$')
ax2.set_title('K and Early M Dwarfs')
ax2.set_xlim(boundx)
ax2.set_ylim(boundy)
ax2.grid()
ax2.invert_yaxis()
plt.show()

# %%
plt.rcParams.update({'font.size': 16})
col1='rmag_PS1'
col2='W1mag_AllWISE'
mag='rmag_PS1'
boundx=(3,8.5)
boundy=(9,18)

fig = plt.figure(figsize=(23,10))
ax = fig.add_subplot(1, 2, 1)
density=ax.scatter(data[col1][ev_M_cols & (data['M_H']!=99.)]-data[col2][ev_M_cols & (data['M_H']!=99.)],data[mag][ev_M_cols & (data['M_H']!=99.)]+5*np.log10(1e-3*data['PLX_GaiaDR2'][ev_M_cols & (data['M_H']!=99.)])+5,marker='.',c=data['M_H'][ev_M_cols & (data['M_H']!=99.)],vmin=-1,vmax=0.5)
#ax.grid()
fig.colorbar(density, label='Gaussian Proccess Regressor M/H')
ax.set_xlabel(r'$r-W1$')
ax.set_ylabel(r'$M_r$')
ax.set_title('M Dwarfs')
ax.set_xlim(boundx)
ax.set_ylim(boundy)
ax.grid()
ax.invert_yaxis()

ax2 = fig.add_subplot(1, 2, 2)
density=ax2.scatter(data[col1][ev_M_cols & (data['M_H']!=99.)]-data[col2][ev_M_cols & (data['M_H']!=99.)],data[mag][ev_M_cols & (data['M_H']!=99.)]+5*np.log10(1e-3*data['PLX_GaiaDR2'][ev_M_cols & (data['M_H']!=99.)])+5,marker='.',c=data['M_H_std'][ev_M_cols & (data['M_H']!=99.)]*1.95,vmin=0.2,vmax=0.75)
#ax.grid()
fig.colorbar(density, label=r'Gaussian Proccess Regressor $1.95\sigma_{M/H}$')
ax2.set_xlabel(r'$r-W1$')
ax2.set_ylabel(r'$M_r$')
ax2.set_title('M Dwarfs')
ax2.set_xlim(boundx)
ax2.set_ylim(boundy)
ax2.grid()
ax2.invert_yaxis()
plt.show()
